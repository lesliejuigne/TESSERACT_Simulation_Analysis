# %% [markdown]
# # TESSERACT Simulation Analysis (TESSSA) - Notebook Demo

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# This notebook aim to present the TESSSA.0.1.
# The code is composed of :
#
# 1. **root_to_h5** : process the simulations.root data into h5py files
#
# 2. **shield_sim_processing** :take the processed data in entry and analyse them

# %% [markdown]
# > **Note:** The current version of the detector geometry implemented in **GEANT4** is **v4.5**.

# %%
import shield_sim_processing as ssp
import root_to_h5 as rth5

# %% [markdown]
# The .h5 file is created in the current directory. To save it elsewhere, can be use "savepath"

# %%
rth5.RootToH5PY("/disk/data1/lze/ljuign/TESSERACT_Simulation_Analysis/sim_data_example/internals/raw", "internals_tests.h5", "internals")
# Out:
# Processing in progress! Be patient... :)
# 100%|██████████| 1296/1296 [00:23<00:00, 54.29it/s]

# %%
ssp.g4_sim_proc('octa', 'internals','internals_tests.h5',plots = True)
# Out:
# Processing files in internals_tests.h5
